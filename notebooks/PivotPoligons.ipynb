# %%
import geopandas as gpd
from sqlalchemy import create_engine

# Conexión a PostGIS
engine = create_engine('postgresql://postgres:MelonSK998@localhost:5432/Poligonos')

# Función para cargar tablas desde PostGIS
def cargar_tabla(nombre_tabla):
    query = f"SELECT * FROM {nombre_tabla};"
    gdf = gpd.read_postgis(query, engine, geom_col="geom")
    return gdf

# Cargar tablas
print("[INFO] Cargando tablas desde PostGIS...")
gdf_manzana = cargar_tabla("manzana")
gdf_ageb = cargar_tabla("ageb")
gdf_colonia = cargar_tabla("colonia")


print(f"gdf_manzana.columns: {gdf_manzana.columns}")
print(f"gdf_ageb.columns: {gdf_ageb.columns}")
print(f"gdf_colonia.columns: {gdf_colonia.columns}")
# Out:
# [INFO] Cargando tablas desde PostGIS...
# gdf_manzana.columns: Index(['gid', 'id_manzana', 'geom'], dtype='object')
# gdf_ageb.columns: Index(['gid', 'id_ageb', 'geom'], dtype='object')
# gdf_colonia.columns: Index(['ENT', 'CVEDT', 'TERRITORIO', 'DTTOLOC', 'CVEUT', 'NOMBRE_COLONIA',
#        'ID_COLONIA', 'geom'],
#       dtype='object')

# %%
# Validar geometrías y CRS
print("[INFO] Validando geometrías activas y CRS...")
crs_target = "EPSG:4326"
for gdf, name in zip([gdf_manzana, gdf_ageb, gdf_colonia], ["manzana", "ageb", "colonia"]):
    if gdf.crs != crs_target:
        print(f"[WARNING] CRS de {name} no coincide con {crs_target}. Reproyectando...")
        gdf = gdf.to_crs(crs_target)
# Out:
# [INFO] Validando geometrías activas y CRS...

# %%
gdf_manzana = gdf_manzana.rename(columns={"gid": "gid_manzana", "geom": "geom_manzana"}).set_geometry("geom_manzana")
gdf_ageb = gdf_ageb.rename(columns={"gid": "gid_ageb", "geom": "geom_ageb"}).set_geometry("geom_ageb")
gdf_colonia = gdf_colonia.rename(columns={"geom": "GEOM_COLONIA"}).set_geometry("GEOM_COLONIA")

# %%
print(f"gdf_manzana.columns: {gdf_manzana.columns}")
print(f"gdf_ageb.columns: {gdf_ageb.columns}")
print(f"gdf_colonia.columns: {gdf_colonia.columns}")
# Out:
# gdf_manzana.columns: Index(['gid_manzana', 'id_manzana', 'geom_manzana'], dtype='object')
# gdf_ageb.columns: Index(['gid_ageb', 'id_ageb', 'geom_ageb'], dtype='object')
# gdf_colonia.columns: Index(['ENT', 'CVEDT', 'TERRITORIO', 'DTTOLOC', 'CVEUT', 'NOMBRE_COLONIA',
#        'ID_COLONIA', 'GEOM_COLONIA'],
#       dtype='object')

# %%
print(gdf_manzana.count())
print(gdf_ageb.count())
print(gdf_colonia.count())
# Out:
# gid_manzana     4813
# id_manzana      4813
# geom_manzana    4813
# dtype: int64
# gid_ageb     167
# id_ageb      167
# geom_ageb    167
# dtype: int64
# ENT               153
# CVEDT             153
# TERRITORIO        153
# DTTOLOC           153
# CVEUT             153
# NOMBRE_COLONIA    153
# ID_COLONIA        153
# GEOM_COLONIA      153
# dtype: int64

# %%
gdf_manzana = gdf_manzana.rename(columns = lambda x: x.upper()).set_geometry("GEOM_MANZANA")

# %%
gdf_manzana
# Out:
#       GID_MANZANA ID_MANZANA  \
# 0               1          1
# 1               2          2
# 2               3          3
# 3               4          4
# 4               5          5
# ...           ...        ...
# 4808         4809       4809
# 4809         4810       4810
# 4810         4811       4811
# 4811         4812       4812
# 4812         4813       4813
#
#                                            GEOM_MANZANA
# 0     MULTIPOLYGON (((-99.10261 19.31446, -99.10262 ...
# 1     MULTIPOLYGON (((-99.13646 19.33011, -99.13649 ...
# 2     MULTIPOLYGON (((-99.14559 19.31907, -99.14571 ...
# 3     MULTIPOLYGON (((-99.1159 19.33298, -99.1158 19...
# 4     MULTIPOLYGON (((-99.11542 19.33209, -99.11597 ...
# ...                                                 ...
# 4808  MULTIPOLYGON (((-99.1748 19.30872, -99.17484 1...
# 4809  MULTIPOLYGON (((-99.10934 19.32239, -99.10934 ...
# 4810  MULTIPOLYGON (((-99.16319 19.30341, -99.16298 ...
# 4811  MULTIPOLYGON (((-99.10669 19.31207, -99.10665 ...
# 4812  MULTIPOLYGON (((-99.15209 19.32059, -99.152 19...
#
# [4813 rows x 3 columns]

# %%
gdf_ageb = gdf_ageb.rename(columns = lambda x: x.upper()).set_geometry("GEOM_AGEB")

# %%
gdf_ageb
# Out:
#      GID_AGEB ID_AGEB                                          GEOM_AGEB
# 0           1    1307  MULTIPOLYGON (((-99.20241 19.30902, -99.20254 ...
# 1           3    1241  MULTIPOLYGON (((-99.19025 19.33798, -99.1906 1...
# 2           4    0445  MULTIPOLYGON (((-99.14833 19.30045, -99.14819 ...
# 3          44    1228  MULTIPOLYGON (((-99.13051 19.34164, -99.13033 ...
# 4          84    1533  MULTIPOLYGON (((-99.17756 19.3068, -99.17852 1...
# ..        ...     ...                                                ...
# 162       162    1637  MULTIPOLYGON (((-99.16424 19.30835, -99.1646 1...
# 163       163    1641  MULTIPOLYGON (((-99.16316 19.30747, -99.16374 ...
# 164       165    1867  MULTIPOLYGON (((-99.0996 19.32147, -99.09995 1...
# 165       166    1848  MULTIPOLYGON (((-99.11 19.33234, -99.11 19.332...
# 166       167    1833  MULTIPOLYGON (((-99.11 19.33234, -99.11009 19....
#
# [167 rows x 3 columns]

# %%
manzanas_agebs = gpd.sjoin(gdf_manzana, gdf_ageb, how="inner", predicate="within")

# %%
manzanas_agebs
# Out:
#       GID_MANZANA ID_MANZANA  \
# 0               1          1
# 1               2          2
# 2               3          3
# 3               4          4
# 4               5          5
# ...           ...        ...
# 4808         4809       4809
# 4809         4810       4810
# 4810         4811       4811
# 4811         4812       4812
# 4812         4813       4813
#
#                                            GEOM_MANZANA  index_right  \
# 0     MULTIPOLYGON (((-99.10261 19.31446, -99.10262 ...          137
# 1     MULTIPOLYGON (((-99.13646 19.33011, -99.13649 ...           43
# 2     MULTIPOLYGON (((-99.14559 19.31907, -99.14571 ...           74
# 3     MULTIPOLYGON (((-99.1159 19.33298, -99.1158 19...          119
# 4     MULTIPOLYGON (((-99.11542 19.33209, -99.11597 ...          119
# ...                                                 ...          ...
# 4808  MULTIPOLYGON (((-99.1748 19.30872, -99.17484 1...          156
# 4809  MULTIPOLYGON (((-99.10934 19.32239, -99.10934 ...          102
# 4810  MULTIPOLYGON (((-99.16319 19.30341, -99.16298 ...           30
# 4811  MULTIPOLYGON (((-99.10669 19.31207, -99.10665 ...           87
# 4812  MULTIPOLYGON (((-99.15209 19.32059, -99.152 19...          126
#
#       GID_AGEB ID_AGEB
# 0          137    1497
# 1           36    0713
# 2           70    0855
# 3          112    1251
# 4          112    1251
# ...        ...     ...
# 4808       153    1548
# 4809        97    1336
# 4810        23    1660
# 4811        82    150A
# 4812       122    0658
#
# [4785 rows x 6 columns]

# %%
# Mantener geometrías de AGEBS en a nueva columna
manzanas_agebs["GEOM_AGEB"] = gdf_ageb.set_index("ID_AGEB").loc[manzanas_agebs["ID_AGEB"], "GEOM_AGEB"].values

# %%
# Validar columnas resultantes
print("[INFO] Columnas en el GeoDataFrame resultante:")
print(manzanas_agebs.columns)

# Verificar geometrías
print("[INFO] Ejemplo de geometrías resultantes:")
print(manzanas_agebs[["ID_MANZANA", "GEOM_MANZANA", "ID_AGEB", "GEOM_AGEB"]].head())
# Out:
# [INFO] Columnas en el GeoDataFrame resultante:
# Index(['GID_MANZANA', 'ID_MANZANA', 'GEOM_MANZANA', 'index_right', 'GID_AGEB',
#        'ID_AGEB', 'GEOM_AGEB'],
#       dtype='object')
# [INFO] Ejemplo de geometrías resultantes:
#   ID_MANZANA                                       GEOM_MANZANA ID_AGEB  \
# 0          1  MULTIPOLYGON (((-99.10261 19.31446, -99.10262 ...    1497
# 1          2  MULTIPOLYGON (((-99.13646 19.33011, -99.13649 ...    0713
# 2          3  MULTIPOLYGON (((-99.14559 19.31907, -99.14571 ...    0855
# 3          4  MULTIPOLYGON (((-99.1159 19.33298, -99.1158 19...    1251
# 4          5  MULTIPOLYGON (((-99.11542 19.33209, -99.11597 ...    1251
#
#                                            GEOM_AGEB
# 0  MULTIPOLYGON (((-99.10086 19.3139, -99.10095 1...
# 1  MULTIPOLYGON (((-99.13313 19.33264, -99.13278 ...
# 2  MULTIPOLYGON (((-99.1436 19.32085, -99.1434 19...
# 3  MULTIPOLYGON (((-99.11339 19.33147, -99.11345 ...
# 4  MULTIPOLYGON (((-99.11339 19.33147, -99.11345 ...

# %%
if manzanas_agebs.crs != gdf_colonia.crs:
    print("[WARNING] CRS de manzanas_agebs y colonias no coinciden. Reproyectando...")
    gdf_colonia = gdf_colonia.to_crs(manzanas_agebs.crs)

# %%
if "index_right" in manzanas_agebs.columns:
    print("[INFO] Eliminando columna conflictiva 'index_right' en manzanas_agebs.")
    manzanas_agebs = manzanas_agebs.drop(columns=["index_right"])

if "index_right" in gdf_colonia.columns:
    print("[INFO] Eliminando columna conflictiva 'index_right' en gdf_colonia.")
    gdf_colonia = gdf_colonia.drop(columns=["index_right"])
# Out:
# [INFO] Eliminando columna conflictiva 'index_right' en manzanas_agebs.

# %%
print("[INFO] Realizando unión espacial entre manzanas_agebs y colonias...")
manzanas_agebs_colonias = gpd.sjoin(
    manzanas_agebs,
    gdf_colonia,
    how="inner",
    predicate="within",
    lsuffix="manzanas_agebs",
    rsuffix="colonias"
)
# Out:
# [INFO] Realizando unión espacial entre manzanas_agebs y colonias...

# %%
print("[INFO] Agregando geometrías de colonias al resultado...")
manzanas_agebs_colonias = manzanas_agebs_colonias.merge(
    gdf_colonia[["ID_COLONIA", "GEOM_COLONIA"]],
    how="left",
    left_on="ID_COLONIA",
    right_on="ID_COLONIA",
    suffixes=(None, "_colonia")
)
# Out:
# [INFO] Agregando geometrías de colonias al resultado...

# %%
# Validar columnas del resultado final
print("[INFO] Columnas del GeoDataFrame resultante:")
print(manzanas_agebs_colonias.columns)
# Out:
# [INFO] Columnas del GeoDataFrame resultante:
# Index(['GID_MANZANA', 'ID_MANZANA', 'GEOM_MANZANA', 'GID_AGEB', 'ID_AGEB',
#        'GEOM_AGEB', 'index_colonias', 'ENT', 'CVEDT', 'TERRITORIO', 'DTTOLOC',
#        'CVEUT', 'NOMBRE_COLONIA', 'ID_COLONIA', 'GEOM_COLONIA'],
#       dtype='object')

# %%
manzanas_agebs_colonias = manzanas_agebs_colonias.rename(columns = lambda x: x.upper())

# %%
manzanas_agebs_colonias
# Out:
#       GID_MANZANA ID_MANZANA  \
# 0               1          1
# 1               2          2
# 2               4          4
# 3               5          5
# 4               6          6
# ...           ...        ...
# 4455         4808       4808
# 4456         4809       4809
# 4457         4810       4810
# 4458         4811       4811
# 4459         4812       4812
#
#                                            GEOM_MANZANA  GID_AGEB ID_AGEB  \
# 0     MULTIPOLYGON (((-99.10261 19.31446, -99.10262 ...       137    1497
# 1     MULTIPOLYGON (((-99.13646 19.33011, -99.13649 ...        36    0713
# 2     MULTIPOLYGON (((-99.1159 19.33298, -99.1158 19...       112    1251
# 3     MULTIPOLYGON (((-99.11542 19.33209, -99.11597 ...       112    1251
# 4     MULTIPOLYGON (((-99.10704 19.31626, -99.10704 ...        80    1406
# ...                                                 ...       ...     ...
# 4455  MULTIPOLYGON (((-99.16328 19.35649, -99.16319 ...        22    0037
# 4456  MULTIPOLYGON (((-99.1748 19.30872, -99.17484 1...       153    1548
# 4457  MULTIPOLYGON (((-99.10934 19.32239, -99.10934 ...        97    1336
# 4458  MULTIPOLYGON (((-99.16319 19.30341, -99.16298 ...        23    1660
# 4459  MULTIPOLYGON (((-99.10669 19.31207, -99.10665 ...        82    150A
#
#                                               GEOM_AGEB  INDEX_COLONIAS ENT  \
# 0     MULTIPOLYGON (((-99.10086 19.3139, -99.10095 1...              34   9
# 1     MULTIPOLYGON (((-99.13313 19.33264, -99.13278 ...              14   9
# 2     MULTIPOLYGON (((-99.11339 19.33147, -99.11345 ...              37   9
# 3     MULTIPOLYGON (((-99.11339 19.33147, -99.11345 ...              37   9
# 4     MULTIPOLYGON (((-99.10695 19.31526, -99.10743 ...              57   9
# ...                                                 ...             ...  ..
# 4455  MULTIPOLYGON (((-99.16046 19.35804, -99.16045 ...              45   9
# 4456  MULTIPOLYGON (((-99.17565 19.30764, -99.17571 ...             117   9
# 4457  MULTIPOLYGON (((-99.11272 19.32082, -99.1129 1...             119   9
# 4458  MULTIPOLYGON (((-99.1597 19.30393, -99.15962 1...              48   9
# 4459  MULTIPOLYGON (((-99.10473 19.30994, -99.10494 ...              36   9
#
#      CVEDT TERRITORIO DTTOLOC   CVEUT                       NOMBRE_COLONIA  \
# 0        3   COYOACAN      30  03-027  CTM IX CULHUACAN ZONA 29-30 (U HAB)
# 1        3   COYOACAN      30  03-008                               AVANTE
# 2        3   COYOACAN      30  03-029              CTM V CULHUACAN (U HAB)
# 3        3   COYOACAN      30  03-029              CTM V CULHUACAN (U HAB)
# 4        3   COYOACAN      30  03-049              EMILIANO ZAPATA (U HAB)
# ...    ...        ...     ...     ...                                  ...
# 4455     3   COYOACAN      26  03-037                           DEL CARMEN
# 4456     3   COYOACAN      32  03-091                  PEDREGAL DEL MAUREL
# 4457     3   COYOACAN      30  03-093             PILOTO CULHUACAN (U HAB)
# 4458     3   COYOACAN      32  03-041                           EL CARACOL
# 4459     3   COYOACAN      30  03-028            CTM IXA CULHUACAN (U HAB)
#
#       ID_COLONIA                                       GEOM_COLONIA
# 0            249  POLYGON ((-99.10346 19.31297, -99.1034 19.3136...
# 1            190  POLYGON ((-99.13088 19.32602, -99.13064 19.325...
# 2            252  POLYGON ((-99.1129 19.33572, -99.1126 19.33502...
# 3            252  POLYGON ((-99.1129 19.33572, -99.1126 19.33502...
# 4            272  POLYGON ((-99.11369 19.32067, -99.11351 19.320...
# ...          ...                                                ...
# 4455         260  POLYGON ((-99.16258 19.35115, -99.16277 19.350...
# 4456         332  POLYGON ((-99.17645 19.30935, -99.17598 19.309...
# 4457         334  POLYGON ((-99.10921 19.32163, -99.11028 19.321...
# 4458         263  POLYGON ((-99.1641 19.30829, -99.16405 19.3083...
# 4459         251  POLYGON ((-99.10492 19.30903, -99.10441 19.308...
#
# [4460 rows x 15 columns]

# %%
import psycopg2

# Conexión a la base de datos para ejecutar consultas SQL
conn = psycopg2.connect("dbname='Poligonos' user='developer' password='MelonSK998' host='localhost' port='5432'")
cur = conn.cursor()

# Eliminar abla existente de colonias si es necesario
cur.execute("DROP TABLE IF EXISTS poligonos_manzanas_agebs_colonias;")
conn.commit()
conn.close()

# %%
manzanas_agebs_colonias.to_postgis("poligonos_manzanas_agebs_colonias", con=engine, if_exists="replace")

# %%
def cargar_tabla(nombre_tabla, geom):
    query = f"SELECT * FROM {nombre_tabla};"
    gdf = gpd.read_postgis(query, engine, geom_col = f"{geom}")
    #gdf = gdf.rename(columns = {f"{geom}": "geom"})
    return gdf

# %%
nombre_tabla = "poligonos_manzanas_agebs_colonias"
query = f"SELECT * FROM {nombre_tabla};"
gdf = gpd.read_postgis(query, engine, geom_col = "GEOM_MANZANA")

# %%
gdf
# Out:
#       GID_MANZANA ID_MANZANA  \
# 0             865        865
# 1               4          4
# 2            2210       2210
# 3              63         63
# 4               6          6
# ...           ...        ...
# 4398         4806       4806
# 4399         4807       4807
# 4400         4808       4808
# 4401         4811       4811
# 4402         4812       4812
#
#                                            GEOM_MANZANA  GID_AGEB ID_AGEB  \
# 0     MULTIPOLYGON (((-99.14463 19.35059, -99.14468 ...        35    0075
# 1     MULTIPOLYGON (((-99.1159 19.33298, -99.1158 19...       112    1251
# 2     MULTIPOLYGON (((-99.11479 19.32735, -99.11481 ...       156    1285
# 3     MULTIPOLYGON (((-99.13975 19.33591, -99.1398 1...        52    1143
# 4     MULTIPOLYGON (((-99.10704 19.31626, -99.10704 ...        80    1406
# ...                                                 ...       ...     ...
# 4398  MULTIPOLYGON (((-99.16292 19.31146, -99.16286 ...       161    0963
# 4399  MULTIPOLYGON (((-99.14029 19.30328, -99.14006 ...        16    1425
# 4400  MULTIPOLYGON (((-99.16328 19.35649, -99.16319 ...        22    0037
# 4401  MULTIPOLYGON (((-99.16319 19.30341, -99.16298 ...        23    1660
# 4402  MULTIPOLYGON (((-99.10669 19.31207, -99.10665 ...        82    150A
#
#       INDEX_COLONIAS ENT CVEDT TERRITORIO DTTOLOC   CVEUT  \
# 0                 32   9     3   COYOACAN      26  03-025
# 1                 37   9     3   COYOACAN      30  03-029
# 2                 38   9     3   COYOACAN      30  03-030
# 3                 49   9     3   COYOACAN      30  03-042
# 4                 57   9     3   COYOACAN      30  03-049
# ...              ...  ..   ...        ...     ...     ...
# 4398               5   9     3   COYOACAN      32  03-130
# 4399             140   9     3   COYOACAN      32  03-113
# 4400              45   9     3   COYOACAN      26  03-037
# 4401              48   9     3   COYOACAN      32  03-041
# 4402              36   9     3   COYOACAN      30  03-028
#
#                       NOMBRE_COLONIA  ID_COLONIA  \
# 0                       COUNTRY CLUB         247
# 1            CTM V CULHUACAN (U HAB)         252
# 2           CTM VI CULHUACAN (U HAB)         253
# 3                       EL CENTINELA         264
# 4            EMILIANO ZAPATA (U HAB)         272
# ...                              ...         ...
# 4398                      AJUSCO III         181
# 4399  VIEJO EJIDO SANTA URSULA COAPA         355
# 4400                      DEL CARMEN         260
# 4401                      EL CARACOL         263
# 4402       CTM IXA CULHUACAN (U HAB)         251
#
#                                            GEOM_COLONIA  \
# 0     0103000020E61000000100000028000000E52FE8589DC8...
# 1     0103000020E610000001000000450000001BD5BCB939C7...
# 2     0103000020E6100000010000004D0000008BF4646978C7...
# 3     0103000020E6100000010000002A000000C0D85FDF1CC9...
# 4     0103000020E610000001000000310000005BA3E2C346C7...
# ...                                                 ...
# 4398  0103000020E6100000010000004C000000710C7DC8A8CA...
# 4399  0103000020E6100000020000003600000038D62FD80FC9...
# 4400  0103000020E61000000100000057000000876C35B967CA...
# 4401  0103000020E610000001000000430000002FFF3B8A80CA...
# 4402  0103000020E61000000100000025000000375EB80CB7C6...
#
#                                               GEOM_AGEB
# 0     0106000020E61000000100000001030000000100000048...
# 1     0106000020E61000000100000001030000000100000026...
# 2     0106000020E61000000100000001030000000100000026...
# 3     0106000020E61000000100000001030000000100000023...
# 4     0106000020E61000000100000001030000000100000033...
# ...                                                 ...
# 4398  0106000020E6100000010000000103000000010000003C...
# 4399  0106000020E61000000100000001030000000100000039...
# 4400  0106000020E6100000010000000103000000010000001D...
# 4401  0106000020E61000000100000001030000000100000057...
# 4402  0106000020E61000000100000001030000000100000031...
#
# [4403 rows x 15 columns]
